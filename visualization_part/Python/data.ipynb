# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd 
df = pd.read_csv(r"C:\Users\Dhivakar\Downloads\customer_behavior_dataset.csv")
df.head(10)
# Out:
#   Customer ID first_name    last_name  \
# 0    CUST9167  Jashwanth        reddy
# 1    CUST4169   Leenatha        reddy
# 2    CUST2048      Rahul  chenchugari
# 3    CUST2504  Venkatesh  kondaboyina
# 4    CUST8653      tejal         jain
# 5    CUST2106      neelu    ganukalla
# 6    CUST6959   Shashank        reddy
# 7    CUST9153     Khushi         vyas
# 8    CUST4498      Bhanu      Prakash
# 9    CUST6865       Guru  Raghavendra
#
#                                     complete_address phone_number  \
# 0     248 Moore Road Suite 817, Daltonbury, NH 42174   9014341907
# 1  2267 Aguilar Freeway Apt. 652, North Andrew, A...   9110532535
# 2                           USNS Davis, FPO AE 31488   8639033166
# 3  52496 Cook Plain Apt. 015, East Cynthiaborough...   9014828233
# 4     186 Freeman Islands, Jenniferchester, IN 91257   8087791227
# 5          95451 Velazquez Fort, West Eric, CO 16911   8985096649
# 6             797 Green Overpass, Patelton, DE 69024   9380890417
# ...

# %%
device_type_counts = df['Device Type'].value_counts()
device_type_counts
# Out:
# Device Type
# app       3364
# web       3363
# mobile    3273
# Name: count, dtype: int64

# %%
device_percentage = df['Device Type'].value_counts(normalize=True) * 100

device_percentage = device_percentage.round(2)
device_percentage
# Out:
# Device Type
# app       33.64
# web       33.63
# mobile    32.73
# Name: proportion, dtype: float64

# %%
loyalty_count = df['Loyalty Tier'].value_counts()
loyalty_count
# Out:
# Loyalty Tier
# Gold        1245
# Platinum    1202
# Silver      1183
# Name: count, dtype: int64
